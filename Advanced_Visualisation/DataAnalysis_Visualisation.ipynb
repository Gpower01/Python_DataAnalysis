# %% [markdown]
# # Application of Python Data Visualisation
#
# - Here I demonstrated the application of the three most commonly used visualisation libraries:
# - **Matplotlib**
# - **Seaborn**
# - **Pandas-Built-in Data Visualisation tool**
#
# ###  This project utilisese three datasets to demonstrate this concepts :
# - Dataset: tips
# - Dataset: flights
# - Dataset: iris
# - Dataset: titanic from kaggle
# - Dataset: df1, df2 & df3

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# - Simple functional method

# %%
plt.plot(x,y)
plt.show()

# %%
#similar
print('string')
# Out:
# string

# %% [markdown]
# - Adding line style

# %%
plt.plot(x,y,'r--')

# %% [markdown]
# - Adding x labe and y label

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# - Creating multiplots on the same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# - Object oriented API method

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, width and height axes
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.42,0.4,0.4])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.plot(x,y)

# %% [markdown]
# - Creating subplots: rows and columns for example 3x3

# %%
fig, axes = plt.subplots(nrows=3,ncols=3)
plt.tight_layout()#Correcting the overlapping to space out

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a32874310>,
# ...
#       dtype=object)

# %% [markdown]
# - index call axes of the plot separately

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')

plt.tight_layout()# space out plots

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

#Setting title and labels
ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# - Figiure size aspect ratios and DPI (dots or pixels per inch)

# %%
fig = plt.figure(figsize=(8,2),dpi=100)
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# - Subplots

# %%
fig,axes = plt.subplots(nrows=2, ncols=1,figsize=(8,2))
axes[0].plot(x,y,'r-')
axes[1].plot(x,y)

plt.tight_layout()

# %% [markdown]
# - Save figure using 'savefig' method

# %%
fig.savefig('my_picture.png',dpi=200)

# %% [markdown]
# - Two plots with legends
# - Use `ax.legend()` to add legend
# - Use `loc` to specify the location of legends

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label='X Cubed')
ax.plot(x,x**2, label='X Squared')

ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**3, label='X Cubed')
ax.plot(x,x**2, label='X Squared')

ax.legend(loc=(0.1,0.8))# specifying location of legends as 0.1, 0.8

# %% [markdown]
# - Set the plot range, colours, weight and customisation

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='green')#Adding colours

# %% [markdown]
# - Use RGB custome codes

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='#FF8C00') #Tips:Google search RGB Hex Code

# %% [markdown]
# - Line width (lw) and styles

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',linewidth=2,alpha=0.5) #alpha argument to add transparency to the line

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=2,linestyle='--')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=2,ls='-')

# %% [markdown]
# - Using markers

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

#Adding custome colours 
ax.plot(x,y,color='purple',lw=1,ls='-',marker='o', markersize='20',
        markerfacecolor='yellow',markeredgewidth='3',markeredgecolor='green')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple',lw=0.5,ls='-',marker='1', markersize='10')#Adds custome colours

# %%
#Set 'x' and 'y' limit
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='purple',lw=1,ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %% [markdown]
# - Satistical plotting algorithms

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# - Create a figure object called **fig using plt.figure()**, Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# - Create a figure object with two axes: ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# - plot (x,y) and call figure object to display the plot

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

ax1.plot(x,y,'r-')
ax2.plot(x,y,'r-')

ax1.set_xlabel('X')
ax1.set_ylabel('y')
ax1.set_title('Title')

ax2.set_xlabel('X')
ax2.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# - Create a plot with two axes to a figure object located at [0,0,1,1] and [0.2,0.5,.4,.4]

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %% [markdown]
# - Create a figure with x and y limits

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

#for the large plot
ax.plot(x,z)
ax.set_xlabel('X')
ax.set_ylabel('Y')

#insert plot
ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')

#Add limits
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30, 50)

# %% [markdown]
# - Use **plt.subplots(nrows=1, ncols=2)** to create two subplots

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

#plot(x,y) and (x,z) with adjusted linewidth and style
axes[0].plot(x,y,'b--', linewidth=3)
axes[1].plot(x,z,'r',linewidth=3)

plt.tight_layout()#sapce the plots

# %% [markdown]
# - Resize the plots by adding the figure() argument in plt.subplots()

# %%
fig, axes = plt.subplots(1,2,figsize=(12,2))
axes[0].plot(x,y,color='blue',lw=3,ls='--')
axes[1].plot(x,z,color='red',lw=3,ls='-')

# %% [markdown]
# # SEABORN
#
# - Seaborn is a statistical plotting library built on top of Matplotlib
# - It is designed to work well with pandas DataFrame objects
#
# ### Installation: `conda install seaborn` or `pip install seaborn`
#
# **http://seaborn.pydata.org**

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# - Seaborn comes with loads of data that can be used to demonstrate its's syntax and visualisation tools.
# - For this demonstration, I will work with dataset called 'tips'
#
# **Loading tips data from Seaborn**
# - The Dataset 'tips' shows the number of people and gender  of those who tip after a meal in restuarant and how much they gave as tips

# %% [markdown]
# # Dataset 1: Tips

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - Univriate plot (containing one variable)

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# - Remove the Kernel density estimation (kde) from the histogram

# %%
sns.distplot(tips['total_bill'], kde=False)

# %% [markdown]
# - Change the number of bins

# %%
sns.distplot(tips['total_bill'], kde=False, bins=20)

# %% [markdown]
# **Joint plots from Seaborn**
#
# - To accomplish this I will have to first pass in the variable that I want to compare and the dataset
# - For example I will comapare total_bill = x, and tip = y

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# - Add **hue** as kind in the joint plots

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# - Notice that in the graph the areas with more cluster appears darker in the hexagons
# - I will also add a regression argument

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# - Use **kde** to show the density of the area of distribution

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %% [markdown]
# ## Pairplot
#
# - Pairplot is used to plot different pairs of plot in the dataset
# - Pass **hue** argument in categorical data, for example **sex** is a categorical data with `male` and `female`

# %%
sns.pairplot(tips)

# %% [markdown]
# - Pass **hue** to sex
# - Add pallette to add colour style

# %%
sns.pairplot(tips,hue='sex')

# %% [markdown]
# - Add palette='coolwarm'

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# - Use **rugplot**
# - The rug plot is a linear plot that shows the frequency of occurrence along the distribution line

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# - KDE 'kernel density estimation plots'
# - Normal and Gaussian distribution curves (continous probability distribution)
# - Set the bandwidth, for more info: url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

#100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

# Create an empty kernel list
kernel_list = []

for data_point in dataset:
    
    #Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# **Get the kde plot**
#
# - To get the kde plot, I will sum these basis function

# %%
# Plotting the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

#Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Getting rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %% [markdown]
# - Plot kde plots

# %%
sns.kdeplot(tips['total_bill'])

# %% [markdown]
# ## Plot Categorical Data
# - using the tips Dataset

# %%
import seaborn as sns
# %matplotlib inline

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - Visualise a group of action using bar plot

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %% [markdown]
# ## Estimator Argument
#
# - Estimator argument is a statistical function to estimate within a categorical bin
# - By default estimator is an average or mean value but we can also add more arguments

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# - Use countplot in Seaborn
# - To visualise the number of occurrences tips were given by the different gender

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## Boxplot
# - In the plot, 'x' is catagorical and 'y' is numerical

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# ## Customise the boxplot
# - For example add the distribution of people smolking

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %% [markdown]
# ## Violine Plots

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %% [markdown]
# ## Stripplot
# - Use jitter argument to reveal the density of the plot

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',dodge=True)

# %% [markdown]
# ## Swarm Plot

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# ## Combine violine and swarm plots

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %% [markdown]
# ## Catplot
# - **Note: `factorplot` was renamed to `catplot`**

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='bar')

# %% [markdown]
# # Dataset 2: Flights
#
# ### Matrix Plots: using dataset 1 & 2

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Heat Map
# - Heatmap is one of the primary ways of showing matrix plots
# - In order for a heat map to be plotted properly, your data should already be in matrix form

# %% [markdown]
# **Transoform 'tips data'to matrix form; rows and columns**
# - I will do this using either pivot table or correlation approach

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
#Annotating and specifying colors
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# **Transform data to matrix using pivot table approach**

# %%
flights.pivot_table(index='month',columns='year',values='passengers')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp)

# %% [markdown]
# - Specify color as 'magma'

# %%
sns.heatmap(fp,cmap='magma')

# %% [markdown]
# - Line color and linewidth

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=1)

# %%
sns.heatmap(fp,cmap='coolwarm',linecolor='black',linewidths=1)

# %% [markdown]
# ## Cluster map using hierachical approach
# - Clustering algorithm is a useful technique in machine learning

# %%
sns.clustermap(fp,cmap='coolwarm')

# %% [markdown]
# - Normalise the scale to standard '0-1'

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# # Dataset 3: iris
# - The dataset 'iris' contains the measurements of different flower species
#
# ### Grids

# %%
import seaborn as sns
# %matplotlib inline
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# - **Evaluate the species**

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# - Notice that there are three different species
# - Use pairplot to further evaluate their correlation

# %%
sns.pairplot(iris)

# %% [markdown]
# - Customise the plots

# %%
sns.PairGrid(iris)

# %% [markdown]
# - Next I will map the plot with the dataset
# - Set the argument to 'g'

# %%
import matplotlib.pyplot as plt
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %% [markdown]
# - **Add more control arguments**

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# ## FacetGrid
# - I will use dataset 1 (tips)

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')

# %% [markdown]
# - Adding more arguments, for example, time of tips and number of people who are smokers that tips

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# ## REGRESSION PLOTS
# - Applying linear model functions

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %% [markdown]
# - **Add markers**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,row='time')

# %% [markdown]
# - **Combining both row and col**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex')

# %% [markdown]
# - Chang aspect ratio of the plots

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',
          aspect=0.6,height=8)

# %% [markdown]
# - **Plot customisation using style and color**

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=tips)

# %%
#White background
sns.set_style('white')
sns.countplot(x='sex',data=tips)

# %%
#Grids background
sns.set_style('darkgrid')
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)

#remove the spin
sns.despine()

# %% [markdown]
# - Explore different Size and Aspect Ratio

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %% [markdown]
# - Customise context, scale and font size

# %%
sns.set_context('poster')
sns.countplot(x='sex',data=tips)

# %%
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex',data=tips)

# %%
#The default 
sns.set_context('notebook')
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## Pallet and Colors
# - Tips: Google Matplotlib colormaps

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='seismic')

# %% [markdown]
# ## Data Analysis Visualisation Project
#
# - This project uses the **titanic** Dataset from Kaggle

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ## Load Titanic Dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.distplot(titanic['fare'], kde=False, color='red',bins=30)

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')

# %%
sns.countplot(x='sex',data=titanic)

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr')
# Out:
# Text(0.5, 1, 'titanic.corr')

# %% [markdown]
# ## Alternative method

# %%
tc = titanic.corr()

# %%
sns.heatmap(tc,cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %%
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')

# %%
#Alternatively 
g = sns.FacetGrid(data=titanic,col='sex')
g.map(sns.distplot,'age',kde=False)

# %% [markdown]
# ## Pandas Built-in Data Visualisation

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# - Make an Histogram of the 'A' column of df1

# %%
df1['A'].hist()

# %% [markdown]
# - Increase the number of bins

# %%
df1['A'].hist(bins=30)

# %% [markdown]
# ## Alternatively I can use seaborn

# %%
import seaborn as sns
df1['A'].hist(bins=30)

# %% [markdown]
# ## Using DataFrame

# %%
df1['A'].plot(kind='hist')

# %%
df1['A'].plot(kind='hist',bins=20)

# %%
df1['A'].plot.hist(bins=20)

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %% [markdown]
# - **Adding transparency**

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# ### Apply Stack

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# ## Line plots
# - Specify x and y

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(figsize=(12,3),lw=1)

# %% [markdown]
# ## Scatter plots
# - specify color

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %% [markdown]
# **Passing the color as a dataFrame**
# - Multiply the points by 100 to enlarge them

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)

# %% [markdown]
# ## Boxplot

# %%
df2.plot.box()

# %% [markdown]
# ## Build a DataFrame

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.122555 -1.562485
# 1  1.617920  0.237821
# 2  1.044400 -1.990925
# 3 -1.581474  0.226421
# 4 -1.580836  0.172606

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')

# %% [markdown]
# ### KDE plots

# %%
df2['a']
# Out:
# 0    0.039762
# 1    0.937288
# 2    0.780504
# 3    0.672717
# 4    0.053829
# 5    0.286043
# 6    0.430436
# 7    0.312296
# 8    0.187765
# 9    0.908162
# Name: a, dtype: float64

# %%
df2['a'].plot.kde()

# %% [markdown]
# - **Alternatively**

# %%
df2['a'].plot.density()

# %% [markdown]
# - Generate a density plot for the entire DataFrame, enabling comparison of the data distribution

# %%
df2.plot.density()

# %% [markdown]
# ## Data Visualisation Project using Pandas Built-in Data Visualisation
#
# - Load df3 dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df3 = pd.read_csv('df3')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',figsize=(12,3),s=50,c='darkred')

# %%
df3['a'].hist()

# %%
df3['a'].plot.hist(bins=10)

# %% [markdown]
# - Add more bins and change the style
# - For example using 'ggplot'

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=20)

# %% [markdown]
# - Add transparency using alpha

# %%
df3['a'].plot.hist(bins=20,alpha=0.5)

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# - Boxplot data 'a' and 'b'

# %%
df3[['a','b']].plot.box()

# %% [markdown]
# - KDE plot of 'd' column

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.density(lw=4,ls='--')

# %% [markdown]
# - Creat an area plot of all the column up to row 30. (hint: use **.iloc()**)

# %%
#Get the first 30 rows
df3.iloc[0:30]
# Out:
#            a         b         c         d
# 0   0.336272  0.325011  0.001020  0.401402
# 1   0.980265  0.831835  0.772288  0.076485
# 2   0.480387  0.686839  0.000575  0.746758
# 3   0.502106  0.305142  0.768608  0.654685
# 4   0.856602  0.171448  0.157971  0.321231
# 5   0.705973  0.632689  0.504017  0.313622
# 6   0.166724  0.269734  0.608569  0.874427
# 7   0.054041  0.966440  0.065596  0.109448
# 8   0.757839  0.523885  0.527210  0.226936
# 9   0.425383  0.213701  0.049020  0.287598
# 10  0.176837  0.166534  0.779374  0.936486
# 11  0.221546  0.660821  0.811782  0.392565
# 12  0.001350  0.450186  0.076469  0.753368
# 13  0.537323  0.623779  0.071851  0.751200
# 14  0.032284  0.050182  0.897562  0.614129
# 15  0.488804  0.091374  0.203803  0.179708
# 16  0.821116  0.191407  0.756962  0.592383
# 17  0.202699  0.103978  0.342236  0.787626
# 18  0.185218  0.751554  0.612737  0.088429
# 19  0.842810  0.842357  0.206589  0.389940
# 20  0.844033  0.449981  0.132198  0.103938
# ...

# %%
df3.loc[0:30].plot.area(alpha=0.5)

# %% [markdown]
# - Add legend outside the plot to the right

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
#a = {'Test1': {1: 21867186, 4: 20145576, 10: 18018537},
    #'Test2': {1: 23256313, 4: 21668216, 10: 19795367}}

#d = pd.DataFrame(a).T
#print d

#f = plt.figure()

#plt.title('Title here!', color='black')
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#d.plot(kind='bar', ax=f.gca())
#plt.show()

# %%
f = plt.figure()
df3.loc[0:30].plot.area(alpha=0.5)
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.show()

# %%
df3.loc[0:30].plot.area(alpha=0.5)
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))

# %% [markdown]
# ## Great!
