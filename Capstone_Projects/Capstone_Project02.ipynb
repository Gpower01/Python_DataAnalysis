# %% [markdown]
# # Finance Project
#
# ### This project analysed the stocked prices for differnt investment banks.
#
# - It focused on bank stocks and evaluates their progress throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.
#
# Note this project is simply used to illustrate the application of Python Data Analysis and it is not meant to be taken as a financial advice.

# %% [markdown]
# ## Loading the Data
#
# #### This section will demonstrate how to read data directly from 'Google or Yahoo Finance' using pandas.
#
# - But first I will start by importing the required libraries
# - Install pandas-datareader required to read stock information directly from the internet
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**)

# %%
from pandas_datareader import data, wb
import numpy as np
import pandas as pd
from datetime import datetime
# %matplotlib inline
import pandas_datareader.data as web
import pandas_datareader as pdr

# %% [markdown]
# ## Points to Keep in Mind
#
# ### Using pandas datereader, I will get stocks for the following banks:
# - Bank of America
# - CitiGroup
# - Goldman Sachs
# - JPMorgan Chase
# - Morgan Stanley
# - Wells Fargo
#
# ### Approach
#
# ** First I will figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of the bank listed above. Then I will set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# **More detail information: [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# #### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google finance" MAY NOT ALWAYS WORK. For this project I am going to use the "Yahoo Finance" https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %% [markdown]
# - Step 1: I want to set the start and end Date

# %%
start = datetime(2006,1,1)
end = datetime(2016,1,1)

# %% [markdown]
# - Next I will figure out the different ticker for the various Banks

# %%
#for Bank of America 'BAC'
BAC = data.DataReader('BAC', 'yahoo', start, end)

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.054218
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.681938
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.726604
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.674480
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.696808
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.859037
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.730473
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.868218
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.657003
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  15.454980
#
# [2517 rows x 6 columns]

# %%
BAC = web.DataReader('BAC', 'yahoo', start, end)

# %% [markdown]
# - Next I will check for trading stock prices and volume traded that period

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.054218
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.681938
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.726604
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.674480
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.696808
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.859037
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.730473
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.868218
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.657003
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  15.454980
#
# [2517 rows x 6 columns]

# %% [markdown]
# - Now I will try to figure out the stock prices and tickers for other banks
# - Tips: just google search the bank name plus stock ticker and you will find it (eg. Citigroup plus stock ticker)

# %%
# For CitiGroup ('C')
C = web.DataReader('C', 'yahoo', start, end)

# %%
C
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994   1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988   1870900.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012   1143100.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012   1370200.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994   1680700.0
# ...                ...         ...         ...         ...         ...
# 2015-12-24   52.970001   52.450001   52.480000   52.709999   4671200.0
# 2015-12-28   52.570000   51.959999   52.570000   52.380001   8761700.0
# 2015-12-29   53.220001   52.740002   52.759998   52.980000  10155100.0
# 2015-12-30   52.939999   52.250000   52.840000   52.299999   8763300.0
# 2015-12-31   52.389999   51.750000   52.070000   51.750000  11281800.0
#
#              Adj Close
# Date
# 2006-01-03  384.214600
# 2006-01-04  377.121155
# 2006-01-05  378.992065
# ...

# %%
#For Goldman Sachs 'GS'
GS = web.DataReader('GS','yahoo', start, end)

# %%
GS
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  129.440002  124.230003  126.699997  128.869995  6188700.0
# 2006-01-04  128.910004  126.379997  127.349998  127.089996  4861600.0
# 2006-01-05  127.320000  125.610001  126.000000  127.040001  3717400.0
# 2006-01-06  129.250000  127.290001  127.290001  128.839996  4319600.0
# 2006-01-09  130.619995  128.000000  128.500000  130.389999  4723500.0
# ...                ...         ...         ...         ...        ...
# 2015-12-24  183.169998  182.020004  182.270004  182.470001  1107600.0
# 2015-12-28  181.929993  179.839996  181.770004  181.619995  1723300.0
# 2015-12-29  184.179993  182.500000  182.820007  183.529999  1848900.0
# 2015-12-30  183.529999  181.839996  183.279999  182.009995  1514300.0
# 2015-12-31  182.889999  180.029999  181.160004  180.229996  1773900.0
#
#              Adj Close
# Date
# 2006-01-03  106.906731
# 2006-01-04  105.430092
# 2006-01-05  105.388611
# ...

# %%
#for JPMorgan Chase 'JPM'
JPM = web.DataReader('JPM','yahoo',start,end)

# %%
JPM
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  40.360001  39.299999  39.830002  40.189999  12838600.0  27.264044
# 2006-01-04  40.139999  39.419998  39.779999  39.619999  13491500.0  27.106680
# 2006-01-05  39.810001  39.500000  39.610001  39.740002   8109400.0  27.188778
# 2006-01-06  40.240002  39.549999  39.919998  40.020000   7966900.0  27.380350
# 2006-01-09  40.720001  39.880001  39.880001  40.669998  16575200.0  27.825054
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  66.889999  66.320000  66.620003  66.599998   4468200.0  58.061897
# 2015-12-28  66.449997  65.709999  66.290001  66.379997   6610600.0  57.870090
# 2015-12-29  67.300003  66.739998  66.839996  67.070000   9820800.0  58.471645
# 2015-12-30  67.050003  66.449997  67.040001  66.589996   7190700.0  58.053162
# 2015-12-31  66.779999  66.000000  66.190002  66.029999  14654300.0  57.564957
#
# [2517 rows x 6 columns]

# %%
#for Morgan Stanley 'MS'
MS = web.DataReader('MS','yahoo',start,end)

# %%
MS
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  37.170383
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  37.195881
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  37.297882
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  37.336124
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  37.731342
# ...               ...        ...        ...        ...        ...        ...
# 2015-12-24  32.709999  32.439999  32.570000  32.480000  2798200.0  28.914894
# 2015-12-28  32.360001  31.950001  32.360001  32.169998  5420300.0  28.638926
# 2015-12-29  32.700001  32.330002  32.439999  32.549999  6388200.0  28.977213
# 2015-12-30  32.650002  32.200001  32.500000  32.230000  5057200.0  28.692335
# 2015-12-31  32.299999  31.770000  31.910000  31.809999  8154300.0  28.318438
#
# [2517 rows x 6 columns]

# %%
#for Wells Fargo 'WFC'
WFC = web.DataReader('WFC','yahoo', start,end)

# %%
WFC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  31.975000  31.195000  31.600000  31.900000  11016400.0  20.818630
# 2006-01-04  31.820000  31.365000  31.799999  31.530001  10870000.0  20.577162
# 2006-01-05  31.555000  31.309999  31.500000  31.495001  10158000.0  20.554317
# 2006-01-06  31.775000  31.385000  31.580000  31.680000   8403800.0  20.675053
# 2006-01-09  31.825001  31.555000  31.674999  31.674999   5619600.0  20.671791
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  55.090000  54.709999  54.970001  54.820000   4999400.0  46.593655
# 2015-12-28  54.779999  54.169998  54.549999  54.680000   8288800.0  46.474667
# 2015-12-29  55.349998  54.990002  55.110001  55.290001   7894900.0  46.993126
# 2015-12-30  55.310001  54.790001  55.270000  54.889999   8016900.0  46.653145
# 2015-12-31  54.950001  54.220001  54.509998  54.360001  10929800.0  46.202682
#
# [2517 rows x 6 columns]

# %% [markdown]
# - **Next I will combine the dataFrames together**

# %%
# Bank of America 
BAC = data.DataReader('BAC', 'yahoo', start, end)

# CitiGroup
C = web.DataReader('C', 'yahoo', start, end)

# Goldman Sachs
GS = web.DataReader('GS','yahoo', start, end)

# JPMorgan Chase
JPM = web.DataReader('JPM','yahoo',start,end)

# Morgan Stanley
MS = web.DataReader('MS','yahoo',start,end)

# Wells Fargo
WFC = web.DataReader('WFC','yahoo', start,end)

# %% [markdown]
# - **Step 2: I will create a list with the ticker symbols in alphabetical order and I will call this tickers**
# - Use pd.concat() to concatenate the bank DataFrames together into a single DataFrame called bank_stocks. Setting the keys argument equal to tickers list. Also paying attention to what axis to concatenate on.

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
# To concatenate into a single column, I will pass axis=1 and the keys argument to tickers
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.054218
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.681938
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.726604
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.674480
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.696808
#
#                      C                                      ...         MS  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  57.169998
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  58.700001
# ...

# %% [markdown]
# - Set the column name levels using the name arguement

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.054218  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   34.681938  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   34.726604  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# - Notice that I have succesfully created the Data file containing the information I needed from all the banks. This data is similar to the data file I already created in csv

# %%
#call the 'all_banks csv file' using 'df'
df = pd.read_pickle('all_banks')

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %% [markdown]
# - Notice that the csv file is the same as the one I created above

# %% [markdown]
# ## Performing Exploratory Data Analysis
# - Using multi-indexing and pandas.DataFrame.xs argument to grab different data from the banks
#
# ## For more Info:
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.xs.html

# %%
#to grab data from BAC for example
bank_stocks['BAC']
# Out:
# Stock Info       High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.054218
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.681938
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.726604
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.674480
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.696808
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.859037
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.730473
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.868218
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.657003
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  15.454980
#
# [2517 rows x 6 columns]

# %%
bank_stocks['BAC']['Close']
# Out:
# Date
# 2006-01-03    47.080002
# 2006-01-04    46.580002
# 2006-01-05    46.639999
# 2006-01-06    46.570000
# 2006-01-09    46.599998
#                 ...
# 2015-12-24    17.270000
# 2015-12-28    17.129999
# 2015-12-29    17.280001
# 2015-12-30    17.049999
# 2015-12-31    16.830000
# Name: Close, Length: 2517, dtype: float64

# %%
#then maximum 
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %% [markdown]
# - Step 3: I wil get the maximum Close price for each bank stock throughout the the time period

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %% [markdown]
# ### Alternative method
#
# - Set axis=1 because I am peforming the operation in the column and level = stock info
# - Determine the maximum closing price

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %% [markdown]
# - Now I will create a new empty DataFrame called **returns**. This dataframe will contain the returns for each bank's stock. Returns are typically defined by:
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# - I can use pandas **pct_change()** method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.

# %%
# Create a 'for loop'
for tick in tickers:
    returns[tick+ 'Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
#Check the returns dataFrema
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %% [markdown]
# - Step 4: I will create a pairplot using seaborn for the returns dataframe. This will provide more information about which stock stands out and why

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#returns[1:]
sns.pairplot(returns[1:])

# %%
#to start the plot from index '1' (this helps eliminate the 'Nans' in index 0)
sns.pairplot(returns[1:])

# %% [markdown]
# - Use the returns DataFrame to figure out the dates each bank stock traded best and worst in a single day returns. - - Notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?

# %%
# to get the minimum values for all bank returns 
returns.min()
# Out:
# BACReturn   -0.289694
# CReturn     -0.390244
# GSReturn    -0.189596
# JPMReturn   -0.207274
# MSReturn    -0.258929
# WFCReturn   -0.238223
# dtype: float64

# %% [markdown]
# - I actually want the dates that this happens and to do that I will use the **.argmin()**

# %%
returns['BACReturn'].argmin()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
#
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# Timestamp('2009-01-20 00:00:00')

# %% [markdown]
# - **Alternatively I can use'.idxmin()' to eliminate the abvove error message

# %%
returns['BACReturn'].idxmin()
# Out:
# Timestamp('2009-01-20 00:00:00')

# %% [markdown]
# - Now I will perform same task for the entire DataFrame; and you can see that the least and biggest returns correlates with real life events. **To check this 'google search for example JPM 20th January 2009 and see what happend/results**

# %%
returns.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# - Get the biggest single day gains

# %%
returns.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ## Observations
# - You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame?

# %% [markdown]
# - Next I will take a look at the standard deviation for each returns from the banks and identify the riskiest stock  over the entire time period? and for example the riskiest for the year 2015?
#
# **A high standard deviation, implies that the stock was going up and down alot (fluctuating) and a low standard deviation implies that the stock was pretty much steady**

# %%
returns.std()
# Out:
# BACReturn    0.036647
# CReturn      0.038672
# GSReturn     0.025390
# JPMReturn    0.027667
# MSReturn     0.037819
# WFCReturn    0.030238
# dtype: float64

# %% [markdown]
# - Based on the standard deviation, it appears that the Citigroup have the biggest std

# %%
returns
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158
# ...               ...       ...       ...        ...       ...        ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681  -0.003997
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544  -0.002554
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812   0.011156
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831  -0.007235
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031  -0.009656
#
# [2517 rows x 6 columns]

# %% [markdown]
# - Now I will get the values for 2015 standard Deviation using the index
# ### Notice that .ix is deprecated to .loc

# %%
returns.ix['2015-01-01':'2015-12-31'].std()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %% [markdown]
# - Create a distpolot using seaborn for the 2015 returns for Morgan Stanley. Notice that we have a distribution that only deviates about '0.06' from the average

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MSReturn'],color='green',bins=50)

# %% [markdown]
# - A distplot using seaborn for the 2008 returns for CitiGroup. Notice that the standard Deviation is quite very much extending to more than '0.6' compared to the '0.06' in Morgan Stanley. This is indicative of the financial crises that the bank went through in 2008.

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['CReturn'],color='red',bins=50)

# %% [markdown]
# # Applying More Advanced Visualization
#
#  - I will try to use different visualization libraries to recreate the described plots: seaborn, matplotlib, plotly and cufflinks, or just pandas
#
# ### But first I will to setup the environment

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_style('whitegrid')
# %matplotlib inline

import plotly 
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# - First I will try to create a line plot showing the Close price for each of the banks for the entire index of time. (Hint: use a for loop, or use .xs to get a cross section of the data.)

# %% [markdown]
# ## For loop method

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(12,4))
    plt.legend()

# %% [markdown]
# Here you can literally see that CitiGroup crashes after 2008 Global recessions while Goldman Sachs kind of dips in 2008 and back up quite quicly in 2009 after the recession

# %% [markdown]
# ## Similar plot with cross-sectiosn .xs

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info')
# Out:
# Bank Ticker        BAC           C          GS        JPM         MS  \
# Date
# 2006-01-03   47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04   46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05   46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06   46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09   46.599998  483.899994  130.389999  40.669998  59.189999
# ...                ...         ...         ...        ...        ...
# 2015-12-24   17.270000   52.709999  182.470001  66.599998  32.480000
# 2015-12-28   17.129999   52.380001  181.619995  66.379997  32.169998
# 2015-12-29   17.280001   52.980000  183.529999  67.070000  32.549999
# 2015-12-30   17.049999   52.299999  182.009995  66.589996  32.230000
# 2015-12-31   16.830000   51.750000  180.229996  66.029999  31.809999
#
# Bank Ticker        WFC
# Date
# 2006-01-03   31.900000
# 2006-01-04   31.530001
# 2006-01-05   31.495001
# 2006-01-06   31.680000
# ...

# %% [markdown]
# - Now I can use **.plot()**

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %% [markdown]
# ## Matplotlib way of generating the same plots

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>
#
#
#             <div id="85436bdb-37bb-489a-b85b-09337f749747" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("85436bdb-37bb-489a-b85b-09337f749747")) {
#                     Plotly.newPlot(
#                         '85436bdb-37bb-489a-b85b-09337f749747',
# ...

# %% [markdown]
# # Moving Averages
#
# - I will go ahead and analyse the moving averages for the stock market in the year 2008
#
# - Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 day Mov Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# **NOTE: you can change the plot to weekly moving average if you want**

# %% [markdown]
# ### Heatmap
#
# - Create a heatmap showing the correlations between the stocks Close Price.
# - First I will start by building out the DataFrame

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info')
# Out:
# Bank Ticker        BAC           C          GS        JPM         MS  \
# Date
# 2006-01-03   47.080002  492.899994  128.869995  40.189999  58.310001
# 2006-01-04   46.580002  483.799988  127.089996  39.619999  58.349998
# 2006-01-05   46.639999  486.200012  127.040001  39.740002  58.509998
# 2006-01-06   46.570000  486.200012  128.839996  40.020000  58.570000
# 2006-01-09   46.599998  483.899994  130.389999  40.669998  59.189999
# ...                ...         ...         ...        ...        ...
# 2015-12-24   17.270000   52.709999  182.470001  66.599998  32.480000
# 2015-12-28   17.129999   52.380001  181.619995  66.379997  32.169998
# 2015-12-29   17.280001   52.980000  183.529999  67.070000  32.549999
# 2015-12-30   17.049999   52.299999  182.009995  66.589996  32.230000
# 2015-12-31   16.830000   51.750000  180.229996  66.029999  31.809999
#
# Bank Ticker        WFC
# Date
# 2006-01-03   31.900000
# 2006-01-04   31.530001
# 2006-01-05   31.495001
# 2006-01-06   31.680000
# ...

# %% [markdown]
# - **Correlation**

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218  0.008542
# C            0.971516  1.000000  0.434123  0.003515  0.933609 -0.068536
# GS           0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS           0.944218  0.933609  0.683792  0.250427  1.000000  0.131835
# WFC          0.008542 -0.068536  0.499897  0.940269  0.131835  1.000000

# %% [markdown]
# ## Heatmap Plot

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr())

# %%
#include annotation of the closes prices 
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# ## Clustermap

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %% [markdown]
# ## Using Plotly

# %%
close_corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()

# %%
close_corr
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218  0.008542
# C            0.971516  1.000000  0.434123  0.003515  0.933609 -0.068536
# GS           0.550898  0.434123  1.000000  0.685286  0.683792  0.499897
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427  0.940269
# MS           0.944218  0.933609  0.683792  0.250427  1.000000  0.131835
# WFC          0.008542 -0.068536  0.499897  0.940269  0.131835  1.000000

# %% [markdown]
# ### Now I will go ahead and use .plot() and specify the kind

# %%
close_corr.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="09eef93c-ccca-46c1-9892-7614bfcd48ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("09eef93c-ccca-46c1-9892-7614bfcd48ee")) {
#                     Plotly.newPlot(
#                         '09eef93c-ccca-46c1-9892-7614bfcd48ee',
# ...

# %% [markdown]
# ### Using Cufflinks
#
# - First I will install the `cufflinks library` and build the DataFrame
# - Use **.iplot(kind=candle)** to create a candle plot for Bank of America stocks from 1st Jan 2015 to 1st Jan 2016.
# - For the candle plot, I will need to know the High and Low values

# %%
# build the DataFrame ('red= decreasing and Green = increasing')
BAC[['Open','High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
# Out:
#                  Open       High        Low      Close
# Date
# 2015-01-02  17.990000  18.030001  17.680000  17.900000
# 2015-01-05  17.790001  17.809999  17.290001  17.379999
# 2015-01-06  17.420000  17.440001  16.780001  16.860001
# 2015-01-07  17.139999  17.180000  16.870001  16.940001
# 2015-01-08  17.160000  17.340000  17.100000  17.290001
# ...               ...        ...        ...        ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000
# 2015-12-28  17.219999  17.230000  16.980000  17.129999
# 2015-12-29  17.250000  17.350000  17.160000  17.280001
# 2015-12-30  17.200001  17.240000  17.040001  17.049999
# 2015-12-31  17.010000  17.070000  16.830000  16.830000
#
# [252 rows x 4 columns]

# %%
bac15 = BAC[['Open','High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
# Out:
# <div>
#
#
#             <div id="0c0da121-bc8d-4313-829d-515992eb249e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0c0da121-bc8d-4313-829d-515992eb249e")) {
#                     Plotly.newPlot(
#                         '0c0da121-bc8d-4313-829d-515992eb249e',
# ...

# %% [markdown]
# - I will use **.ta_plot(study='sma')** to create a simple moving averages plot of Morgan Stanley for the year 2015.

# %%
plt.figure(figsize=(12,4))
MS['Close'].loc['2015-01-01':'2016-01-01'].rolling(window=30).mean().plot(label='30 day Mov Avg')
MS['Close'].loc['2015-01-01':'2016-01-01'].plot(label='BAC Close')
plt.legend()

# %% [markdown]
# - **Now I can perform some technical analysis and specify some periods**

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55])
# Out:
# <div>
#
#
#             <div id="c83eb7ec-66d9-4e31-a90b-50116bd50cb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c83eb7ec-66d9-4e31-a90b-50116bd50cb8")) {
#                     Plotly.newPlot(
#                         'c83eb7ec-66d9-4e31-a90b-50116bd50cb8',
# ...

# %% [markdown]
# - **Using .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**
#
# - This will show the standard Deviation of the stock prices as it moves up and down (fluctuates).

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div>
#
#
#             <div id="ef8bfb77-17d8-48a4-89f8-cb7d2aca2f4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ef8bfb77-17d8-48a4-89f8-cb7d2aca2f4a")) {
#                     Plotly.newPlot(
#                         'ef8bfb77-17d8-48a4-89f8-cb7d2aca2f4a',
# ...

# %% [markdown]
# # Great Job
